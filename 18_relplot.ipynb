# %% [markdown]
# <a href="https://colab.research.google.com/github/Davron030901/Matplotlib_and_Seaborn/blob/main/18_relplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn: relplot

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Create new column with age decade bucket for each passenger.

# %%
df['decade'] = [age//10*10 for age in df.age]

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  decade
# 0    man        True  NaN  Southampton    no  False    20.0
# 1  woman       False    C    Cherbourg   yes  False    30.0
# 2  woman       False  NaN  Southampton   yes   True    20.0
# 3  woman       False    C  Southampton   yes  False    30.0
# 4    man        True  NaN  Southampton    no   True    30.0

# %% [markdown]
# ## Intro Visuals

# %%
from matplotlib import pyplot as plt

# %%
sns.set(style='darkgrid', font_scale=2)

g = sns.relplot(x='age', y='fare', data=df,
            row='class',
            hue='survived',
            aspect=1.5,
                s=300,
                palette=['black', 'red'],
                style='survived',
                markers=['X', 'o']
           );
g.set_titles(row_template="{row_name} Class")
g.set_xlabels('Passenger Age')
g.set_ylabels('Fare')
leg = g._legend
leg.set_title('Survived');
plt.savefig('18catplot_figure_facetExample.png', dpi=200, bbox_inches='tight')

# %%
sns.set(style='white', font_scale=1.5)

g = sns.relplot(x='age', y='fare',
                data=df,
                col='sex',
                hue='survived',
                aspect=1.7,
                height=3,
                palette=['black', 'red'],
                style='survived',
                markers=['X', 'o'],
                s=120
               )
g.set_titles(col_template="")
g.set_xlabels("")
g.set_ylabels('');
plt.savefig('18catplot_figure_scatterThumb.png', dpi=200)

# %%
g = sns.relplot(x='decade', y='survived',
                data=df[df.age < 70],
                hue='sex',
                col='sex',
                aspect=1.7,
                height=3,
                palette=['black', 'red'],
                style='sex',
                lw=3,
                kind='line'
               )
g.set_titles(col_template="")
g.set_xlabels("")
g.set_ylabels('');
plt.savefig('18catplot_figure_lineThumb.png', dpi=200)

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('axes', labelsize=10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('white')

# %%
sns.relplot(x='age', y='fare', data=df)

# %% [markdown]
# ### Categorical Variables: Hue, Style, Size

# %%
sns.relplot(x='age', y='fare',
            data=df,
            hue='pclass',
            style='pclass',
            size='pclass'
           )

# %% [markdown]
# ### Kind

# %%
sns.relplot(x='age', y='fare', data=df, kind='line')

# %%
sns.relplot(x='decade', y='fare', data=df, kind='line')

# %%
sns.relplot(x='decade', y='fare',
            data=df,
            kind='line',
            hue='pclass',
            style='pclass'
           )

# %% [markdown]
# ## Small Multiples (FacetGrid)

# %% [markdown]
# ### `row`, `col`

# %%
sns.relplot(x='age', y='fare',
            data=df,
            col='pclass'
           )

# %%
sns.relplot(x='decade', y='fare',
            data=df,
            kind='line',
            col='pclass'
           )

# %%
sns.relplot(x='decade', y='fare',
            data=df,
            kind='line',
            row='pclass'
           )

# %% [markdown]
# ### `col_wrap`

# %%
sns.relplot(x='age', y='fare',
            data=df,
            col='deck',
            col_wrap=3
           )

# %% [markdown]
# ## Styling

# %% [markdown]
# In general, additional keyword arguments will be passed to the kind of plot selected.

# %%
sns.relplot(x='age', y='fare', data=df,
            col='pclass',
            hue='survived',
            s=150,
            palette=['black', 'red'],
            marker='^'
           )

# %% [markdown]
# ### `markers`, `sizes`

# %%
sns.relplot(x='age', y='fare', data=df,
            col='pclass',
            hue='survived',
            s = 150,
            palette=['black', 'red'],
            style='survived',
            markers=['X', 'o']
           )

# %% [markdown]
# ### FacetGrid Styling

# %%
g = sns.relplot(x='decade', y='survived',
                data=df[df.age < 70],
                kind='line',
                hue='sex',
                errorbar=None
               )

# %%
type(g)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
g = sns.relplot(x='decade', y='survived',
                data=df[df.age < 70],
                kind='line',
                hue='sex',
                errorbar=None,
                col='pclass'
               )

g.set_xlabels('Passenger Age Group')
g.set_ylabels("Percent Survived");
